# %%
import math
import matplotlib.pyplot as plt

# %%
EPS_START = 0.9
EPS_END = 0.1
def decay(rate, steps_done):
    eps_threshold = rate * steps_done + 1
    return eps_threshold

# %%
d = []
for i in range(1000000):
    d.append(decay(-0.0000009, i))
plt.plot(d)

# %%
d[-1]
# Out:
# 0.10000090000000006
