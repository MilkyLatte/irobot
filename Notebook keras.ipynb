# %%
import matplotlib.pyplot as plt

from keras.models import Sequential, load_model
from keras.layers import Dense, Convolution2D, Flatten
from keras.optimizers import RMSprop
import tensorflow as tf

import gym
import numpy as np
import math
import cv2
import random
from collections import deque, namedtuple

from wrappers import wrap_deepmind
# Out:
# Using TensorFlow backend.

# %%
env = wrap_deepmind(gym.make('BreakoutNoFrameskip-v4'))

# %%
env = gym.make('BreakoutNoFrameskip-v4')

n_actions = env.action_space.n


class DeepQNet():
    def __init__(self, n_actions, height, width):
        self.model = Sequential()
        self.model.add(Convolution2D(filters=32, kernel_size=8, strides=4, activation='relu', input_shape=(height, width, 4)))
        self.model.add(Convolution2D(filters=64, kernel_size=4, strides=2, activation='relu'))
        self.model.add(Convolution2D(filters=64, kernel_size=3, strides=1, activation='relu'))

        self.model.add(Flatten())
        self.model.add(Dense(units=512, activation='relu'))
        self.model.add(Dense(units=n_actions))
        self.model.compile(loss='mse', optimizer=RMSprop(lr=0.00025,
                                             rho=0.95,
                                             epsilon=0.01))

# %%
Experience = namedtuple('Experience', field_names=['state', 'action', 'reward', 'done', 'new_state'])



class ReplayMemory:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def __len__(self):
        return len(self.buffer)

    def append(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        states, actions, rewards, dones, next_states = zip(*[self.buffer[idx] for idx in indices])
        return np.array(states), np.array(actions), np.array(rewards, dtype=np.float32), \
               np.array(dones, dtype=np.uint8), np.array(next_states)

# %%
def get_epsilon(current_step):
    rate = (EPS_END-EPS_START)/MEM_SIZE
    eps_threshold = rate * current_step + EPS_START
    if eps_threshold < EPS_END:
        return EPS_END
    return eps_threshold


def select_action(state, steps_done, eval=False):
    global EPSILON

    # This equation is for the decaying epsilon
    eps_threshold = get_epsilon(steps_done)

    if eval:
        eps_threshold = EPS_END

    r = np.random.rand()

    EPSILON = eps_threshold

    # We select an action with an espilon greedy policy
    if r > eps_threshold:
        # Return the action with the maximum Q value for the current state
        return np.argmax(policy_net.model.predict(state)[0])
    else:
        return random.randrange(n_actions)

# %%
def optimize_model():
    if memory.__len__() < BATCH_SIZE:
        return 0
    states, actions, rewards, dones, next_states = memory.sample(BATCH_SIZE)
       
    state_action_values = policy_net.model.predict(states)
    next_state_values = np.amax(target_net.model.predict(next_states), axis=1)
    next_state_values[dones] = 0.0
    
    expected_state_action_values = next_state_values * GAMMA + rewards
    state_action_values[:,actions] = expected_state_action_values
    # Compute Huber loss
    history = policy_net.model.fit(states, state_action_values, verbose=False)

    return history.history['loss'][0]

# %%
BATCH_SIZE = 32
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
NUMBER_OF_FRAMES = 5000000
TARGET_UPDATE = 10000


HEIGHT = 84
WIDTH = 84
EPSILON = 0
MEM_SIZE = 1000000

policy_net = DeepQNet(n_actions, HEIGHT, WIDTH)
target_net = DeepQNet(n_actions, HEIGHT, WIDTH)

memory = ReplayMemory(int(MEM_SIZE))

# %%
def train_model(num_frames):
    env = gym.make('BreakoutNoFrameskip-v4')
    env = wrap_deepmind(env)
    cumulative_frames = 0
    
    highest_score = 0
    current_cum_loss = []
    current_game_score = 0
    new_game = True
    games = 0
    
    losses = []
    scores = []
    while cumulative_frames < num_frames:
        if new_game:
            print("============================")
            print("Game: {} | Frame {}".format(games, cumulative_frames))
            new_game = False
        state = env.reset()
        done = False

        while not done:
            action = select_action(state.__array__().reshape(-1, 84, 84, 4), cumulative_frames)

            next_state, reward, done, info = env.step(action)
            
            memory.append(Experience(state, action, reward, done, next_state))

            state = next_state
            loss = optimize_model()
            
            current_cum_loss.append(loss)
            
            current_game_score += reward
            cumulative_frames += 1
            
            if info['ale.lives'] == 0:
                if highest_score < current_game_score:
                    highest_score = current_game_score
                    
                current_loss = np.mean(current_cum_loss)
                losses.append(current_loss)
                scores.append(current_game_score)
                
                print("Current game score: {}".format(current_game_score))
                print("Current loss: {}".format(current_loss))
                print("Highest Score: {}".format(highest_score))
                print("Average loss last 50 games: {}".format(np.mean(losses[-50:])))
                print("Average score last 50 games: {}".format(np.mean(scores[-50:])))
                
                current_game_score = 0
                current_cum_loss = []
                new_game = True
                games += 1
                

        if cumulative_frames % TARGET_UPDATE == 0:
            target_net.model.set_weights(policy_net.model.get_weights())

    target_net.model.save('my_model.h5')
    return losses, scores

# %%
loss, score = train_model(10000000)
# Out:
# ============================
# Game: 0 | Frame 0
# Current game score: 0.0
# Current loss: 0.4921145833813046
# Highest Score: 0
# Average loss last 50 games: 0.4921145833813046
# Average score last 50 games: 0.0
# ============================
# Game: 1 | Frame 475
# Current game score: 0.0
# Current loss: 0.5731401985099441
# Highest Score: 0
# Average loss last 50 games: 0.5326273909456244
# Average score last 50 games: 0.0
# ============================
# Game: 2 | Frame 950
# Current game score: 0.0
# Current loss: 0.4629847489179749
# Highest Score: 0
# Average loss last 50 games: 0.509413176936408
# Average score last 50 games: 0.0
# ============================
# Game: 3 | Frame 1425
# Current game score: 1.0
# Current loss: 0.42594967315096804
# Highest Score: 1.0
# Average loss last 50 games: 0.48854730099004795
# Average score last 50 games: 0.25
# ============================
# Game: 4 | Frame 2014
# Current game score: 0.0
# Current loss: 0.5029596574006504
# Highest Score: 1.0
# Average loss last 50 games: 0.49142977227216844
# Average score last 50 games: 0.2
# ============================
# Game: 5 | Frame 2489
# Current game score: 0.0
# Current loss: 0.45387893924195516
# Highest Score: 1.0
# Average loss last 50 games: 0.4851713001004663
# Average score last 50 games: 0.16666666666666666
# ============================
# Game: 6 | Frame 2964
# Current game score: 1.0
# Current loss: 0.4134669594675212
# Highest Score: 1.0
# Average loss last 50 games: 0.4749278228671884
# Average score last 50 games: 0.2857142857142857
# ============================
# Game: 7 | Frame 3625
# Current game score: 0.0
# Current loss: 0.4055027353724367
# Highest Score: 1.0
# Average loss last 50 games: 0.4662496869303444
# Average score last 50 games: 0.25
# ============================
# Game: 8 | Frame 4100
# Current game score: 0.0
# Current loss: 0.39142782990477587
# Highest Score: 1.0
# Average loss last 50 games: 0.4579361472608368
# Average score last 50 games: 0.2222222222222222
# ============================
# Game: 9 | Frame 4575
# Current game score: 0.0
# Current loss: 0.37339723753889925
# Highest Score: 1.0
# Average loss last 50 games: 0.4494822562886431
# Average score last 50 games: 0.2
# ============================
# Game: 10 | Frame 5050
# Current game score: 0.0
# Current loss: 0.3772887964742748
# Highest Score: 1.0
# Average loss last 50 games: 0.4429192144873369
# Average score last 50 games: 0.18181818181818182
# ============================
# Game: 11 | Frame 5525
# Current game score: 1.0
# Current loss: 0.4180578372309993
# Highest Score: 1.0
# Average loss last 50 games: 0.4408474330493088
# Average score last 50 games: 0.25
# ============================
# Game: 12 | Frame 6114
# Current game score: 0.0
# Current loss: 0.3944982729538491
# Highest Score: 1.0
# Average loss last 50 games: 0.43728211304196574
# Average score last 50 games: 0.23076923076923078
# ============================
# Game: 13 | Frame 6589
# Current game score: 0.0
# Current loss: 0.40243612326485545
# Highest Score: 1.0
# Average loss last 50 games: 0.4347931137721721
# Average score last 50 games: 0.21428571428571427
# ============================
# Game: 14 | Frame 7064
# Current game score: 0.0
# Current loss: 0.3870665287736215
# Highest Score: 1.0
# Average loss last 50 games: 0.43161134143893537
# Average score last 50 games: 0.2
# ============================
# Game: 15 | Frame 7539
# Current game score: 1.0
# Current loss: 0.3847858697189324
# Highest Score: 1.0
# Average loss last 50 games: 0.4286847494564352
# Average score last 50 games: 0.25
# ============================
# Game: 16 | Frame 8202
# Current game score: 1.0
# Current loss: 0.3580695702151907
# Highest Score: 1.0
# Average loss last 50 games: 0.42453091538342086
# Average score last 50 games: 0.29411764705882354
# ============================
# Game: 17 | Frame 8863
# Current game score: 1.0
# Current loss: 0.37403400996544944
# Highest Score: 1.0
# Average loss last 50 games: 0.4217255317490891
# Average score last 50 games: 0.3333333333333333
# ============================
# Game: 18 | Frame 9524
# Current game score: 1.0
# Current loss: 0.3707193352152423
# Highest Score: 1.0
# Average loss last 50 games: 0.41904099508941295
# Average score last 50 games: 0.3684210526315789
# ============================
# Game: 19 | Frame 10185
# Current game score: 0.0
# Current loss: 0.3712745725559561
# Highest Score: 1.0
# Average loss last 50 games: 0.41665267396274014
# Average score last 50 games: 0.35
# ============================
# Game: 20 | Frame 10660
# Current game score: 2.0
# Current loss: 0.3607802753696091
# Highest Score: 2.0
# Average loss last 50 games: 0.41399208355354344
# Average score last 50 games: 0.42857142857142855
# ============================
# Game: 21 | Frame 11523
# Current game score: 0.0
# Current loss: 0.35871770248846396
# Highest Score: 2.0
# Average loss last 50 games: 0.41147961168694897
# Average score last 50 games: 0.4090909090909091
# ============================
# Game: 22 | Frame 11998
# Current game score: 2.0
# Current loss: 0.39750313842526186
# Highest Score: 2.0
# Average loss last 50 games: 0.41087193893644075
# Average score last 50 games: 0.4782608695652174
# ============================
# Game: 23 | Frame 12845
# Current game score: 0.0
# Current loss: 0.39449812831357123
# Highest Score: 2.0
# Average loss last 50 games: 0.4101896968271545
# Average score last 50 games: 0.4583333333333333
# ============================
# Game: 24 | Frame 13320
# Current game score: 0.0
# Current loss: 0.3641561844003828
# Highest Score: 2.0
# Average loss last 50 games: 0.4083483563300836
# Average score last 50 games: 0.44
# ============================
# Game: 25 | Frame 13795
# Current game score: 1.0
# Current loss: 0.39421697279299234
# Highest Score: 2.0
# Average loss last 50 games: 0.40780484157865704
# Average score last 50 games: 0.46153846153846156
# ============================
# Game: 26 | Frame 14384
# Current game score: 3.0
# Current loss: 0.39757802993167524
# Highest Score: 3.0
# Average loss last 50 games: 0.407426070776917
# Average score last 50 games: 0.5555555555555556
# ============================
# Game: 27 | Frame 15295
# Current game score: 0.0
# Current loss: 0.363019136174729
# Highest Score: 3.0
# Average loss last 50 games: 0.4058401088268389
# Average score last 50 games: 0.5357142857142857
# ============================
# Game: 28 | Frame 15770
# Current game score: 0.0
# Current loss: 0.37261945129225127
# Highest Score: 3.0
# Average loss last 50 games: 0.4046945689118531
# Average score last 50 games: 0.5172413793103449
# ============================
# Game: 29 | Frame 16245
# Current game score: 0.0
# Current loss: 0.3853052326331013
# Highest Score: 3.0
# Average loss last 50 games: 0.40404825770256136
# Average score last 50 games: 0.5
# ============================
# Game: 30 | Frame 16720
# Current game score: 0.0
# Current loss: 0.3723407573213703
# Highest Score: 3.0
# Average loss last 50 games: 0.4030254351096197
# Average score last 50 games: 0.4838709677419355
# ============================
# Game: 31 | Frame 17195
# Current game score: 0.0
# Current loss: 0.3721457104130011
# Highest Score: 3.0
# Average loss last 50 games: 0.4020604437128503
# Average score last 50 games: 0.46875
# ============================
# Game: 32 | Frame 17670
# Current game score: 0.0
# Current loss: 0.3573001062203395
# Highest Score: 3.0
# Average loss last 50 games: 0.4007040698494409
# Average score last 50 games: 0.45454545454545453
# ============================
# Game: 33 | Frame 18145
# Current game score: 0.0
# Current loss: 0.3911449845605775
# Highest Score: 3.0
# Average loss last 50 games: 0.4004229202821214
# Average score last 50 games: 0.4411764705882353
# ============================
# Game: 34 | Frame 18620
# Current game score: 0.0
# Current loss: 0.33756473223237615
# Highest Score: 3.0
# Average loss last 50 games: 0.3986269720521287
# Average score last 50 games: 0.42857142857142855
# ============================
# Game: 35 | Frame 19095
# Current game score: 0.0
# Current loss: 0.36782517098870715
# Highest Score: 3.0
# Average loss last 50 games: 0.39777136646703365
# Average score last 50 games: 0.4166666666666667
# ============================
# Game: 36 | Frame 19570
# Current game score: 0.0
# Current loss: 0.3447928504856597
# Highest Score: 3.0
# Average loss last 50 games: 0.3963395146837533
# Average score last 50 games: 0.40540540540540543
# ============================
# Game: 37 | Frame 20045
# Current game score: 0.0
# Current loss: 0.3206725296731058
# Highest Score: 3.0
# Average loss last 50 games: 0.3943482782361047
# Average score last 50 games: 0.39473684210526316
# ============================
# Game: 38 | Frame 20520
# Current game score: 1.0
# Current loss: 0.38800616440680186
# Highest Score: 3.0
# Average loss last 50 games: 0.3941856599327892
# Average score last 50 games: 0.41025641025641024
# ============================
# Game: 39 | Frame 21187
# Current game score: 2.0
# Current loss: 0.4107142587610562
# Highest Score: 3.0
# Average loss last 50 games: 0.3945988749034959
# Average score last 50 games: 0.45
# ============================
# Game: 40 | Frame 21972
# Current game score: 0.0
# Current loss: 0.33335270262862504
# Highest Score: 3.0
# Average loss last 50 games: 0.393105065823621
# Average score last 50 games: 0.43902439024390244
# ============================
# Game: 41 | Frame 22447
# Current game score: 0.0
# Current loss: 0.34874801772793657
# Highest Score: 3.0
# Average loss last 50 games: 0.39204894563086656
# Average score last 50 games: 0.42857142857142855
# ============================
# Game: 42 | Frame 22922
# Current game score: 0.0
# Current loss: 0.3525430474136221
# Highest Score: 3.0
# Average loss last 50 games: 0.39113020381186087
# Average score last 50 games: 0.4186046511627907
# ============================
# Game: 43 | Frame 23397
# Current game score: 1.0
# Current loss: 0.3464208022684985
# Highest Score: 3.0
# Average loss last 50 games: 0.3901140810495117
# Average score last 50 games: 0.4318181818181818
# ============================
# Game: 44 | Frame 23986
# Current game score: 0.0
# Current loss: 0.36590848495693584
# Highest Score: 3.0
# Average loss last 50 games: 0.3895761789141211
# Average score last 50 games: 0.4222222222222222
# ============================
# Game: 45 | Frame 24461
# Current game score: 0.0
# Current loss: 0.32231123165864695
# Highest Score: 3.0
# Average loss last 50 games: 0.38811389745204566
# Average score last 50 games: 0.41304347826086957
# ============================
# Game: 46 | Frame 24936
# Current game score: 0.0
# Current loss: 0.35352443845256376
# Highest Score: 3.0
# Average loss last 50 games: 0.38737795151588644
# Average score last 50 games: 0.40425531914893614
# ============================
# Game: 47 | Frame 25411
# Current game score: 0.0
# Current loss: 0.3389353671356251
# Highest Score: 3.0
# Average loss last 50 games: 0.38636873100796437
# Average score last 50 games: 0.3958333333333333
# ============================
# Game: 48 | Frame 25886
# Current game score: 0.0
# Current loss: 0.3469414350885506
# Highest Score: 3.0
# Average loss last 50 games: 0.3855640923157314
# Average score last 50 games: 0.3877551020408163
# ============================
# Game: 49 | Frame 26361
# Current game score: 0.0
# Current loss: 0.32932301041130957
# Highest Score: 3.0
# Average loss last 50 games: 0.38443927067764294
# Average score last 50 games: 0.38
# ============================
# Game: 50 | Frame 26836
# Current game score: 0.0
# Current loss: 0.42624809045932793
# Highest Score: 3.0
# Average loss last 50 games: 0.3831219408192035
# Average score last 50 games: 0.38
# ============================
# Game: 51 | Frame 27311
# Current game score: 0.0
# Current loss: 0.3110833805524989
# Highest Score: 3.0
# Average loss last 50 games: 0.3778808044600545
# Average score last 50 games: 0.38
# ============================
# Game: 52 | Frame 27786
# Current game score: 0.0
# Current loss: 0.31145107734360195
# Highest Score: 3.0
# Average loss last 50 games: 0.3748501310285671
# Average score last 50 games: 0.38
# ============================
# Game: 53 | Frame 28261
# Current game score: 0.0
# Current loss: 0.32610537567617076
# Highest Score: 3.0
# Average loss last 50 games: 0.37285324507907114
# Average score last 50 games: 0.36
# ============================
# Game: 54 | Frame 28736
# Current game score: 0.0
# Current loss: 0.3086921365088538
# Highest Score: 3.0
# Average loss last 50 games: 0.3689678946612352
# Average score last 50 games: 0.36
# ============================
# Game: 55 | Frame 29211
# Current game score: 2.0
# Current loss: 0.3352003539666053
# Highest Score: 3.0
# Average loss last 50 games: 0.36659432295572814
# Average score last 50 games: 0.4
# ============================
# Game: 56 | Frame 29986
# Current game score: 0.0
# Current loss: 0.3084291916203342
# Highest Score: 3.0
# Average loss last 50 games: 0.3644935675987845
# Average score last 50 games: 0.38
# ============================
# Game: 57 | Frame 30461
# Current game score: 0.0
# Current loss: 0.32397365130288036
# Highest Score: 3.0
# Average loss last 50 games: 0.3628629859173933
# Average score last 50 games: 0.38
# ============================
# Game: 58 | Frame 30936
# Current game score: 0.0
# Current loss: 0.32609902684625824
# Highest Score: 3.0
# Average loss last 50 games: 0.3615564098562229
# Average score last 50 games: 0.38
# ============================
# Game: 59 | Frame 31411
# Current game score: 1.0
# Current loss: 0.3293618766794811
# Highest Score: 3.0
# Average loss last 50 games: 0.36067570263903453
# Average score last 50 games: 0.4
# ============================
# Game: 60 | Frame 32078
# Current game score: 0.0
# Current loss: 0.331837231184503
# Highest Score: 3.0
# Average loss last 50 games: 0.3597666713332392
# Average score last 50 games: 0.4
# ============================
# Game: 61 | Frame 32553
# Current game score: 0.0
# Current loss: 0.3358467175909563
# Highest Score: 3.0
# Average loss last 50 games: 0.3581224489404384
# Average score last 50 games: 0.38
# ============================
# Game: 62 | Frame 33028
# Current game score: 0.0
# Current loss: 0.31800044320131604
# Highest Score: 3.0
# Average loss last 50 games: 0.3565924923453877
# Average score last 50 games: 0.38
# ============================
# Game: 63 | Frame 33503
# Current game score: 0.0
# Current loss: 0.33419166579058296
# Highest Score: 3.0
# Average loss last 50 games: 0.35522760319590224
# Average score last 50 games: 0.38
# ============================
# Game: 64 | Frame 33978
# Current game score: 0.0
# Current loss: 0.3163765519097643
# Highest Score: 3.0
# Average loss last 50 games: 0.35381380365862514
# Average score last 50 games: 0.38
# ============================
# Game: 65 | Frame 34453
# Current game score: 0.0
# Current loss: 0.29625162431970237
# Highest Score: 3.0
# Average loss last 50 games: 0.3520431187506404
# Average score last 50 games: 0.36
# ============================
# Game: 66 | Frame 34928
# Current game score: 0.0
# Current loss: 0.2896254566885335
# Highest Score: 3.0
# Average loss last 50 games: 0.3506742364801073
# Average score last 50 games: 0.34
# ============================
# Game: 67 | Frame 35403
# Current game score: 0.0
# Current loss: 0.3132931119046713
# Highest Score: 3.0
# Average loss last 50 games: 0.34945941851889173
# Average score last 50 games: 0.32
# ============================
# Game: 68 | Frame 35878
# Current game score: 0.0
# Current loss: 0.31284483602564583
# Highest Score: 3.0
# Average loss last 50 games: 0.34830192853509984
# Average score last 50 games: 0.3
# ============================
# Game: 69 | Frame 36353
# Current game score: 0.0
# Current loss: 0.4047240839271169
# Highest Score: 3.0
# Average loss last 50 games: 0.3489709187625231
# Average score last 50 games: 0.3
# ============================
# Game: 70 | Frame 36828
# Current game score: 1.0
# Current loss: 0.28996530545208166
# Highest Score: 3.0
# Average loss last 50 games: 0.3475546193641725
# Average score last 50 games: 0.28
# ============================
# Game: 71 | Frame 37417
# Current game score: 0.0
# Current loss: 0.3080483924538681
# Highest Score: 3.0
# Average loss last 50 games: 0.3465412331634806
# Average score last 50 games: 0.28
# ============================
# Game: 72 | Frame 37892
# Current game score: 0.0
# Current loss: 0.2974452381796743
# Highest Score: 3.0
# Average loss last 50 games: 0.3445400751585689
# Average score last 50 games: 0.24
# ============================
# Game: 73 | Frame 38367
# Current game score: 0.0
# Current loss: 0.38640408842383245
# Highest Score: 3.0
# Average loss last 50 games: 0.34437819436077405
# Average score last 50 games: 0.24
# ============================
# Game: 74 | Frame 38842
# Current game score: 1.0
# Current loss: 0.3021685928406735
# Highest Score: 3.0
# Average loss last 50 games: 0.34313844252957976
# Average score last 50 games: 0.26
# ============================
# Game: 75 | Frame 39431
# Current game score: 1.0
# Current loss: 0.2879510972239217
# Highest Score: 3.0
# Average loss last 50 games: 0.3410131250181984
# Average score last 50 games: 0.26
# ============================
# Game: 76 | Frame 40096
# Current game score: 0.0
# Current loss: 0.4046282208299166
# Highest Score: 3.0
# Average loss last 50 games: 0.3411541288361633
# Average score last 50 games: 0.2
# ============================
# Game: 77 | Frame 40571
# Current game score: 0.0
# Current loss: 0.27821371003985407
# Highest Score: 3.0
# Average loss last 50 games: 0.3394580203134657
# Average score last 50 games: 0.2
# ============================
# Game: 78 | Frame 41046
# Current game score: 0.0
# Current loss: 0.2830079308995291
# Highest Score: 3.0
# Average loss last 50 games: 0.33766578990561136
# Average score last 50 games: 0.2
# ============================
# Game: 79 | Frame 41521
# Current game score: 3.0
# Current loss: 0.2945897733146636
# Highest Score: 3.0
# Average loss last 50 games: 0.3358514807192426
# Average score last 50 games: 0.26
# ============================
# Game: 80 | Frame 42484
# Current game score: 0.0
# Current loss: 0.3190014656986061
# Highest Score: 3.0
# Average loss last 50 games: 0.33478469488678725
# Average score last 50 games: 0.26
# ============================
# Game: 81 | Frame 42959
# Current game score: 0.0
# Current loss: 0.2831857586416759
# Highest Score: 3.0
# Average loss last 50 games: 0.33300549585136074
# Average score last 50 games: 0.26
# ============================
# Game: 82 | Frame 43434
# Current game score: 0.0
# Current loss: 0.2948702116173349
# Highest Score: 3.0
# Average loss last 50 games: 0.33175689795930074
# Average score last 50 games: 0.26
# ============================
# Game: 83 | Frame 43909
# Current game score: 0.0
# Current loss: 0.28746681155734943
# Highest Score: 3.0
# Average loss last 50 games: 0.32968333449923615
# Average score last 50 games: 0.26
# ============================
# Game: 84 | Frame 44384
# Current game score: 0.0
# Current loss: 0.2927622789360191
# Highest Score: 3.0
# Average loss last 50 games: 0.328787285433309
# Average score last 50 games: 0.26
# ============================
# Game: 85 | Frame 44859
# Current game score: 0.0
# Current loss: 0.2879853045038487
# Highest Score: 3.0
# Average loss last 50 games: 0.32719048810361184
# Average score last 50 games: 0.26
# ============================
# Game: 86 | Frame 45334
# Current game score: 4.0
# Current loss: 0.2844532711529836
# Highest Score: 4.0
# Average loss last 50 games: 0.32598369651695835
# Average score last 50 games: 0.34
# ============================
# Game: 87 | Frame 46507
# Current game score: 0.0
# Current loss: 0.2929113599520765
# Highest Score: 4.0
# Average loss last 50 games: 0.3254284731225377
# Average score last 50 games: 0.34
# ============================
# Game: 88 | Frame 46982
# Current game score: 2.0
# Current loss: 0.3485630085698402
# Highest Score: 4.0
# Average loss last 50 games: 0.3246396100057985
# Average score last 50 games: 0.36
# ============================
# Game: 89 | Frame 47759
# Current game score: 1.0
# Current loss: 0.30385570657868033
# Highest Score: 4.0
# Average loss last 50 games: 0.322502438962151
# Average score last 50 games: 0.34
# ============================
# Game: 90 | Frame 48348
# Current game score: 0.0
# Current loss: 0.30569778577865736
# Highest Score: 4.0
# Average loss last 50 games: 0.3219493406251517
# Average score last 50 games: 0.34
# ============================
# Game: 91 | Frame 48823
# Current game score: 0.0
# Current loss: 0.29875222475905167
# Highest Score: 4.0
# Average loss last 50 games: 0.32094942476577387
# Average score last 50 games: 0.34
# ============================
# Game: 92 | Frame 49298
# Current game score: 0.0
# Current loss: 0.2775010205991566
# Highest Score: 4.0
# Average loss last 50 games: 0.3194485842294846
# Average score last 50 games: 0.34
# ============================
# Game: 93 | Frame 49773
# Current game score: 0.0
# Current loss: 0.2909353055981429
# Highest Score: 4.0
# Average loss last 50 games: 0.3183388742960775
# Average score last 50 games: 0.32
# ============================
# Game: 94 | Frame 50248
# Current game score: 0.0
# Current loss: 0.25919330427521153
# Highest Score: 4.0
# Average loss last 50 games: 0.316204570682443
# Average score last 50 games: 0.32
# ============================
# Game: 95 | Frame 50723
# Current game score: 1.0
# Current loss: 0.2845542787468114
# Highest Score: 4.0
# Average loss last 50 games: 0.3154494316242063
# Average score last 50 games: 0.34
# ============================
# Game: 96 | Frame 51390
# Current game score: 0.0
# Current loss: 0.2906959085244881
# Highest Score: 4.0
# Average loss last 50 games: 0.3141928610256448
# Average score last 50 games: 0.34
# ============================
# Game: 97 | Frame 51865
# Current game score: 0.0
# Current loss: 0.28655651098019197
# Highest Score: 4.0
# Average loss last 50 games: 0.31314528390253615
# Average score last 50 games: 0.34
# ============================
# Game: 98 | Frame 52340
# Current game score: 0.0
# Current loss: 0.301389827547889
# Highest Score: 4.0
# Average loss last 50 games: 0.31223425175172287
# Average score last 50 games: 0.34
# ============================
# Game: 99 | Frame 52815
# Current game score: 0.0
# Current loss: 0.35759211336507607
# Highest Score: 4.0
# Average loss last 50 games: 0.3127996338107982
# Average score last 50 games: 0.34
# ============================
# Game: 100 | Frame 53290
# Current game score: 0.0
# Current loss: 0.2910734230142675
# Highest Score: 4.0
# Average loss last 50 games: 0.31009614046189704
# Average score last 50 games: 0.34
# ============================
# Game: 101 | Frame 53765
# Current game score: 1.0
# Current loss: 0.28150379915030266
# Highest Score: 4.0
# Average loss last 50 games: 0.3095045488338531
# Average score last 50 games: 0.36
# ============================
# Game: 102 | Frame 54426
# Current game score: 0.0
# Current loss: 0.2848660150934991
# Highest Score: 4.0
# Average loss last 50 games: 0.308972847588851
# Average score last 50 games: 0.36
# ============================
# Game: 103 | Frame 54901
# Current game score: 0.0
# Current loss: 0.27759101045366963
# Highest Score: 4.0
# Average loss last 50 games: 0.30800256028440104
# Average score last 50 games: 0.36
# ============================
# Game: 104 | Frame 55376
# Current game score: 3.0
# Current loss: 0.26505288547787825
# Highest Score: 4.0
# Average loss last 50 games: 0.3071297752637815
# Average score last 50 games: 0.42
# ============================
# Game: 105 | Frame 56357
# Current game score: 1.0
# Current loss: 0.28379763291624577
# Highest Score: 4.0
# Average loss last 50 games: 0.3061017208427743
# Average score last 50 games: 0.4
# ============================
# Game: 106 | Frame 57018
# Current game score: 1.0
# Current loss: 0.3069136779397016
# Highest Score: 4.0
# Average loss last 50 games: 0.30607141056916165
# Average score last 50 games: 0.42
# ============================
# Game: 107 | Frame 57607
# Current game score: 2.0
# Current loss: 0.29132272555115724
# Highest Score: 4.0
# Average loss last 50 games: 0.3054183920541272
# Average score last 50 games: 0.46
# ============================
# Game: 108 | Frame 58464
# Current game score: 0.0
# Current loss: 0.3192076795783482
# Highest Score: 4.0
# Average loss last 50 games: 0.305280565108769
# Average score last 50 games: 0.46
# ============================
# Game: 109 | Frame 58939
# Current game score: 0.0
# Current loss: 0.2986843867639178
# Highest Score: 4.0
# Average loss last 50 games: 0.3046670153104577
# Average score last 50 games: 0.44
# ============================
# Game: 110 | Frame 59414
# Current game score: 5.0
# Current loss: 0.3086039070871938
# Highest Score: 5.0
# Average loss last 50 games: 0.30420234882851155
# Average score last 50 games: 0.54
# ============================
# Game: 111 | Frame 60623
# Current game score: 0.0
# Current loss: 0.3119447765244465
# Highest Score: 5.0
# Average loss last 50 games: 0.30372431000718136
# Average score last 50 games: 0.54
# ============================
# Game: 112 | Frame 61098
# Current game score: 0.0
# Current loss: 0.32080009093312056
# Highest Score: 5.0
# Average loss last 50 games: 0.3037803029618174
# Average score last 50 games: 0.54
# ============================
# Game: 113 | Frame 61573
# Current game score: 0.0
# Current loss: 0.39653581336924903
# Highest Score: 5.0
# Average loss last 50 games: 0.30502718591339073
# Average score last 50 games: 0.54
# ============================
# Game: 114 | Frame 62048
# Current game score: 0.0
# Current loss: 0.3275509106034511
# Highest Score: 5.0
# Average loss last 50 games: 0.3052506730872645
# Average score last 50 games: 0.54
# ============================
# Game: 115 | Frame 62523
# Current game score: 2.0
# Current loss: 0.34232002957043245
# Highest Score: 5.0
# Average loss last 50 games: 0.3061720411922791
# Average score last 50 games: 0.58
# ============================
# Game: 116 | Frame 63378
# Current game score: 0.0
# Current loss: 0.3393810879948892
# Highest Score: 5.0
# Average loss last 50 games: 0.3071671538184062
# Average score last 50 games: 0.58
# ============================
# Game: 117 | Frame 63853
# Current game score: 2.0
# Current loss: 0.38151429281114546
# Highest Score: 5.0
# Average loss last 50 games: 0.3085315774365357
# Average score last 50 games: 0.62
# ============================
# Game: 118 | Frame 64630
# Current game score: 2.0
# Current loss: 0.37055517312925246
# Highest Score: 5.0
# Average loss last 50 games: 0.3096857841786078
# Average score last 50 games: 0.66
# ============================
# Game: 119 | Frame 65495
# Current game score: 0.0
# Current loss: 0.37249573771302635
# Highest Score: 5.0
# Average loss last 50 games: 0.30904121725432604
# Average score last 50 games: 0.66
# ============================
# Game: 120 | Frame 65970
# Current game score: 0.0
# Current loss: 0.3199014390907005
# Highest Score: 5.0
# Average loss last 50 games: 0.3096399399270984
# Average score last 50 games: 0.64
# ============================
# Game: 121 | Frame 66445
# Current game score: 0.0
# Current loss: 0.33006059987666575
# Highest Score: 5.0
# Average loss last 50 games: 0.3100801840755544
# Average score last 50 games: 0.64
# ============================
# Game: 122 | Frame 66920
# Current game score: 1.0
# Current loss: 0.3325191186292839
# Highest Score: 5.0
# Average loss last 50 games: 0.3107816616845465
# Average score last 50 games: 0.66
# ============================
# Game: 123 | Frame 67585
# Current game score: 1.0
# Current loss: 0.30400073688938983
# Highest Score: 5.0
# Average loss last 50 games: 0.30913359465385776
# Average score last 50 games: 0.68
# ============================
# Game: 124 | Frame 68174
# Current game score: 0.0
# Current loss: 0.3049196550936291
# Highest Score: 5.0
# Average loss last 50 games: 0.30918861589891683
# Average score last 50 games: 0.66
# ============================
# Game: 125 | Frame 68649
# Current game score: 1.0
# Current loss: 0.31048503969376984
# Highest Score: 5.0
# Average loss last 50 games: 0.30963929474831375
# Average score last 50 games: 0.66
# ============================
# Game: 126 | Frame 69238
# Current game score: 0.0
# Current loss: 0.3150990673556532
# Highest Score: 5.0
# Average loss last 50 games: 0.3078487116788285
# Average score last 50 games: 0.66
# ============================
# Game: 127 | Frame 69713
# Current game score: 1.0
# Current loss: 0.308479898199692
# Highest Score: 5.0
# Average loss last 50 games: 0.30845403544202527
# Average score last 50 games: 0.68
# ============================
# Game: 128 | Frame 70302
# Current game score: 0.0
# Current loss: 0.3156978229648973
# Highest Score: 5.0
# Average loss last 50 games: 0.30910783328333263
# Average score last 50 games: 0.68
# ============================
# Game: 129 | Frame 70777
# Current game score: 0.0
# Current loss: 0.31419546316279784
# Highest Score: 5.0
# Average loss last 50 games: 0.3094999470802954
# Average score last 50 games: 0.62
# ============================
# Game: 130 | Frame 71252
# Current game score: 2.0
# Current loss: 0.3313450537782684
# Highest Score: 5.0
# Average loss last 50 games: 0.3097468188418886
# Average score last 50 games: 0.66
# ============================
# Game: 131 | Frame 71959
# Current game score: 0.0
# Current loss: 0.33067085243957606
# Highest Score: 5.0
# Average loss last 50 games: 0.31069652071784654
# Average score last 50 games: 0.66
# ============================
# Game: 132 | Frame 72434
# Current game score: 1.0
# Current loss: 0.32374486014100406
# Highest Score: 5.0
# Average loss last 50 games: 0.3112740136883199
# Average score last 50 games: 0.68
# ============================
# Game: 133 | Frame 73095
# Current game score: 0.0
# Current loss: 0.3199034748640598
# Highest Score: 5.0
# Average loss last 50 games: 0.31192274695445416
# Average score last 50 games: 0.68
# ============================
# Game: 134 | Frame 73570
# Current game score: 1.0
# Current loss: 0.32086594656966816
# Highest Score: 5.0
# Average loss last 50 games: 0.3124848203071271
# Average score last 50 games: 0.7
# ============================
# Game: 135 | Frame 74159
# Current game score: 0.0
# Current loss: 0.3071435214843797
# Highest Score: 5.0
# Average loss last 50 games: 0.31286798464673776
# Average score last 50 games: 0.7
# ============================
# Game: 136 | Frame 74634
# Current game score: 1.0
# Current loss: 0.32494613487515067
# Highest Score: 5.0
# Average loss last 50 games: 0.31367784192118103
# Average score last 50 games: 0.64
# ============================
# Game: 137 | Frame 75297
# Current game score: 0.0
# Current loss: 0.3129661693306346
# Highest Score: 5.0
# Average loss last 50 games: 0.3140789381087522
# Average score last 50 games: 0.64
# ============================
# Game: 138 | Frame 75772
# Current game score: 0.0
# Current loss: 0.3132440162744177
# Highest Score: 5.0
# Average loss last 50 games: 0.31337255826284377
# Average score last 50 games: 0.6
# ============================
# Game: 139 | Frame 76247
# Current game score: 0.0
# Current loss: 0.33931401830681257
# Highest Score: 5.0
# Average loss last 50 games: 0.3140817244974064
# Average score last 50 games: 0.58
# ============================
# Game: 140 | Frame 76722
# Current game score: 0.0
# Current loss: 0.33635863831364793
# Highest Score: 5.0
# Average loss last 50 games: 0.31469494154810623
# Average score last 50 games: 0.58
# ============================
# Game: 141 | Frame 77197
# Current game score: 0.0
# Current loss: 0.3106891763318134
# Highest Score: 5.0
# Average loss last 50 games: 0.31493368057956145
# Average score last 50 games: 0.58
# ============================
# Game: 142 | Frame 77672
# Current game score: 0.0
# Current loss: 0.3156168212290657
# Highest Score: 5.0
# Average loss last 50 games: 0.31569599659215963
# Average score last 50 games: 0.58
# ============================
# Game: 143 | Frame 78147
